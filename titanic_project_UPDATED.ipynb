# %% [markdown]
# # 🛳 Titanic Survival Analysis - EDA Project
# This project explores the Titanic dataset to understand which features influenced the survival of passengers.

# %% [markdown]
# ## 🔹 Step 1: Import Required Libraries
# We import Pandas for data handling, Matplotlib and Seaborn for data visualization.

# %% [markdown]
# ## 🔹 Step 1: Load the Titanic Dataset
# We load the dataset directly from Seaborn's built-in Titanic data.

# %%
import seaborn as sns
import pandas as pd

# Load the Titanic dataset
df = sns.load_dataset('titanic')

# Show first 5 rows
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df.columns)

# %% [markdown]
# ## 🔹 Step 2: Understand the Data Structure
# We'll view the first few rows and basic information about the dataset.

# %%
# Check data types and missing values
print(df.info())
# Show count of missing values in each column
print(df.isnull().sum())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None
# survived         0
# pclass           0
# sex              0
# ...

# %% [markdown]
# ## 🔹 Step 3: Data Cleaning
# Check for missing values or incorrect data types (if needed).

# %% [markdown]
# ### Handling Missing Values
# We fill missing values in 'embarked' and 'embark_town' with their respective modes.

# %%
if 'deck' in df.columns:
    df.drop(columns=['deck'], inplace=True)
df['age'] = df['age'].fillna(df['age'].median())
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])
print(df.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## 🔹 Step 4: Survival Analysis by Gender
# Let's see how gender influenced survival.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set theme
sns.set(style="whitegrid")

# Plot survival by gender
sns.countplot(x='sex', hue='survived', data=df)
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## 🔹 Step 5: Survival Analysis by Passenger Class
# We visualize the relationship between Pclass (passenger class) and survival.

# %%
sns.countplot(x='pclass', hue='survived', data=df)
plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## ✅ Final Observations
#
# - More women survived than men.
# - Passengers in 1st class had higher chances of survival.
# - 3rd class had the most casualties.

# %% [markdown]
# ## Conclusion
# This analysis explored the Titanic dataset using Seaborn. We visualized survival rates across gender, class, age, and embarkation points. Women had higher survival rates than men, and passengers in first class were more likely to survive.
